# %% [markdown]
# ##  Python script to demonstrate use of the Bessel functions from the scipy scientific library.
#
# Programmers:  Dick Furnstahl  furnstahl.1@osu.edu and Ralf Bundschuh   bundschuh.2@osu.edu
#
# Revision history:
#    - 12/28/09  original Python version, from j0_test.py
#    - 12/20/21  converted to python 3
#
# Notes:
#    - to learn more about the special functions in scipy:
#     `>>> from scipy import special`
#     `>>> help(special)    # list special functions`
#
#    - One known value:  J0(5) = -1.775967713143382920e-01

# %% [markdown]
# Import the scipy library to have access to the Bessel function

# %%
from scipy import special

# %% [markdown]
# Choose a value and call two different functions from the scipy library

# %%
x = 5.0   # just a random test value

answer = special.j0(x)   # see the scipy manual for details
answer2 = special.jn(0, x)  # more general

# %% [markdown]
# These print statements are directly taken from the scripted version of the code

# %%
print('These answers should be accurate to about 16 significant figures.\n')
print('Using j0:  J0(%.2f) = %.20e' % (x, answer))
print('Using jn:  J0(%.2f) = %.20e' % (x, answer2))
# Out:
# These answers should be accurate to about 16 significant figures.
#
# Using j0:  J0(5.00) = -1.77596771314338292003e-01
# Using jn:  J0(5.00) = -1.77596771314338347514e-01

# %% [markdown]
# You can also look at the value of a variable by just typing its name

# %%
answer
# Out:
# np.float64(-0.1775967713143383)

# %%
answer2
# Out:
# np.float64(-0.17759677131433835)
